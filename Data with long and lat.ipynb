# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
response = requests.get(url).text

# %%
from bs4 import SoupStrainer

data = BeautifulSoup(response, "lxml")

# %%
def is_the_only_string_within_a_tag(s):
    return (s == s.parent.string)

data1 = data.find_all(string=is_the_only_string_within_a_tag)

# %%
data2 = data1[29:893]

# %%
print(len(data2))
# Out:
# 864

# %%
PostCode = data2[0:862:3]
Borough = data2[1:863:3]
Neighborhood = data2[2:864:3]

# %%
import pandas as pd
d = {'PostCode': PostCode, 'Borough': Borough, 'Neighborhood': Neighborhood}
df = pd.DataFrame(data = d)

# %%
data1 = df.loc[df['Borough'] != 'Not assigned']

# %%
data1.head(10)
data1 = data1.reset_index(drop = True)

# %%
#data1['Neighborhood'] = data1['Neighborhood'].str.replace('Not assigned', 'Queen"s Park')

# %%
data1.to_csv('Table')

# %%
data = pd.read_csv('Table')

# %%
data['Neighborhood'] = data['Neighborhood'].str.replace('Not assigned', "Queen's Park").str.replace('\n', '')
data.head(11)
# Out:
#     Unnamed: 0 PostCode           Borough      Neighborhood
# 0            0      M3A        North York         Parkwoods
# 1            1      M4A        North York  Victoria Village
# 2            2      M5A  Downtown Toronto      Harbourfront
# 3            3      M5A  Downtown Toronto       Regent Park
# 4            4      M6A        North York  Lawrence Heights
# 5            5      M6A        North York    Lawrence Manor
# 6            6      M7A      Queen's Park      Queen's Park
# 7            7      M9A         Etobicoke  Islington Avenue
# 8            8      M1B       Scarborough             Rouge
# 9            9      M1B       Scarborough           Malvern
# 10          10      M3B        North York   Don Mills North

# %%
data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data.head()
# Out:
#   PostCode           Borough      Neighborhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights

# %%
data.shape
# Out:
# (211, 3)

# %%
url = 'http://cocl.us/Geospatial_data'
coordinates = pd.read_csv(url)

# %%
coordinates.tail(20)
# Out:
#     Postal Code   Latitude  Longitude
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054

# %%
data1 = data.sort_values('PostCode')

# %%
data1['Latitude'] = coordinates.Latitude
data1['Longitude'] = coordinates.Longitude

# %%
data1.reset_index(inplace=True)

# %%
data1.drop('index', axis = 1, inplace=True)

# %%
data1.head(100)
# Out:
#    PostCode           Borough              Neighborhood   Latitude  Longitude
# 0       M1B       Scarborough                     Rouge  43.716316 -79.239476
# 1       M1B       Scarborough                   Malvern  43.692657 -79.264848
# 2       M1C       Scarborough                Port Union  43.752758 -79.400049
# 3       M1C       Scarborough                Rouge Hill  43.770120 -79.408493
# 4       M1C       Scarborough            Highland Creek  43.789053 -79.408493
# 5       M1E       Scarborough                 Guildwood  43.761631 -79.520999
# 6       M1E       Scarborough               Morningside  43.725882 -79.315572
# 7       M1E       Scarborough                 West Hill  43.706397 -79.309937
# 8       M1G       Scarborough                    Woburn  43.705369 -79.349372
# 9       M1H       Scarborough                 Cedarbrae  43.659526 -79.340923
# 10      M1J       Scarborough       Scarborough Village  43.657162 -79.378937
# 11      M1K       Scarborough      East Birchmount Park  43.662696 -79.400049
# 12      M1K       Scarborough                   Ionview  43.653206 -79.400049
# 13      M1K       Scarborough              Kennedy Park  43.628947 -79.394420
# 14      M1L       Scarborough               Golden Mile  43.691116 -79.476013
# 15      M1L       Scarborough                  Oakridge  43.673185 -79.487262
# 16      M1L       Scarborough                  Clairlea  43.713756 -79.490074
# 17      M1M       Scarborough                Cliffcrest  43.667856 -79.532242
# 18      M1M       Scarborough  Scarborough Village West  43.643515 -79.577201
# 19      M1M       Scarborough                 Cliffside  43.650943 -79.554724
# 20      M1N       Scarborough            Cliffside West        NaN        NaN
# 21      M1N       Scarborough               Birch Cliff        NaN        NaN
# 22      M1P       Scarborough           Wexford Heights        NaN        NaN
# 23      M1P       Scarborough               Dorset Park        NaN        NaN
# 24      M1P       Scarborough   Scarborough Town Centre        NaN        NaN
# 25      M1R       Scarborough                  Maryvale        NaN        NaN
# 26      M1R       Scarborough                   Wexford        NaN        NaN
# 27      M1S       Scarborough                 Agincourt        NaN        NaN
# 28      M1T       Scarborough                  Sullivan        NaN        NaN
# 29      M1T       Scarborough            Clarks Corners        NaN        NaN
# ..      ...               ...                       ...        ...        ...
# 70      M4J         East York              East Toronto  43.647177 -79.381576
# 71      M4K      East Toronto         The Danforth West  43.709577 -79.445073
# 72      M4K      East Toronto                 Riverdale  43.693781 -79.428191
# 73      M4L      East Toronto          The Beaches West  43.662301 -79.389494
# 74      M4L      East Toronto              India Bazaar  43.636966 -79.615819
# 75      M4M      East Toronto           Studio District  43.696319 -79.532242
# 76      M4N   Central Toronto             Lawrence Park        NaN        NaN
# 77      M4P   Central Toronto          Davisville North        NaN        NaN
# 78      M4R   Central Toronto        North Toronto West        NaN        NaN
# 79      M4S   Central Toronto                Davisville        NaN        NaN
# 80      M4T   Central Toronto                Moore Park        NaN        NaN
# 81      M4T   Central Toronto           Summerhill East        NaN        NaN
# 82      M4V   Central Toronto                South Hill        NaN        NaN
# 83      M4V   Central Toronto                 Rathnelly        NaN        NaN
# 84      M4V   Central Toronto           Summerhill West        NaN        NaN
# 85      M4V   Central Toronto                 Deer Park        NaN        NaN
# 86      M4V   Central Toronto            Forest Hill SE        NaN        NaN
# 87      M4W  Downtown Toronto                  Rosedale        NaN        NaN
# 88      M4X  Downtown Toronto               Cabbagetown        NaN        NaN
# 89      M4X  Downtown Toronto            St. James Town        NaN        NaN
# 90      M4Y  Downtown Toronto      Church and Wellesley        NaN        NaN
# 91      M5A  Downtown Toronto               Regent Park  43.770992 -79.216917
# 92      M5A  Downtown Toronto              Harbourfront  43.763573 -79.188711
# 93      M5B  Downtown Toronto                   Ryerson  43.781638 -79.304302
# 94      M5B  Downtown Toronto           Garden District  43.815252 -79.284577
# 95      M5C  Downtown Toronto            St. James Town  43.725900 -79.340923
# 96      M5E  Downtown Toronto               Berczy Park  43.676357 -79.293031
# 97      M5G  Downtown Toronto        Central Bay Street  43.679557 -79.352188
# 98      M5H  Downtown Toronto                      King  43.679563 -79.377529
# 99      M5H  Downtown Toronto                  Adelaide  43.686412 -79.400049
#
# [100 rows x 5 columns]
